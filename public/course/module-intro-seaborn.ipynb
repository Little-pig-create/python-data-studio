# %% [markdown]
# # Seaborn 模块入门
#
# <!-- module-learning-arc:start -->
# > **Seaborn 模块主线｜第 1 / 20 步：建立整洁数据与统计绘图语义**
# >
# > **持续应用背景：** 开展客群消费行为差异研究：先固定样本和统计语义，再比较分布、关系和分面结果，判断差异是否稳定。
# >
# > **承接上一阶段：** 模块入门与应用任务  →  **本章任务：** Seaborn 模块入门  →  **下一步：** 数据结构与主题
# >
# > **大作业连接：** 本章练习将成为《客群消费行为差异研究》的一部分，最终需要从样本口径和分布比较走到关系验证、分面研究与因果边界说明。
# <!-- module-learning-arc:end -->

# %% [markdown]
# ## 学习目标
#
# 完成“Seaborn 模块入门”后，你应该能够：
#
# 1. 能说明一行观察、分组字段和统计量各自代表什么。
# 2. 能选择与问题匹配的统计图，并解释类别或分布差异。
# 3. 能检查排序、样本量和不确定性是否影响结论。

# %% [markdown]
# ## 运行后应观察
#
# 运行示例后，应看到类别、分布或关系的统计图。解读前先确认每个点或条形代表的观察单位和统计量。
#
# 如果暂时没有输出，先确认是否按顺序运行了前置单元格；再检查变量名、数据形状或路径，而不是直接跳到参考实现。

# %% [markdown]
# ## 初学者学习路线
#
# 这章建议按照“先观察、再模仿、后修改、最后独立完成”的顺序学习，不必一次记住所有参数。
#
# 1. 先阅读任务说明，明确这段代码要回答什么问题。
# 2. 运行一个最小例子，先观察输入、输出和数据形状，再回看每一行代码。
# 3. 只修改一个参数或一条数据，重新运行并比较前后结果。
# 4. 完成“综合练习”，最后再看本章小结，把能迁移到其他数据的问题写下来。
#
# 运行时如果看到 NameError，通常是前置单元格还没有运行；如果输出和预期不同，先检查变量是否被后面的单元格重新赋值。

# %% [markdown]
# ## 先做一个小检查
#
# 进入正式例子前，先用一句话回答：本章的输入是什么，想得到什么结果？
#
# 本章主题是“Seaborn 模块入门”。请特别留意三件事：输入的类型或形状、处理中间变量的含义、最后输出能否支持一个清楚的结论。

# %% [markdown]
# ## 本章场景
#
#
#
# 用 Matplotlib 画图很好，但每次都要写一堆设置配色、误差线、分组的代码。当你想"比较几个类别的销售额差异""看两个变量的相关趋势"时，更希望一句话出图。
#
#
#
# **Seaborn** 建立在 Matplotlib 之上，专为**统计图表**设计：给它一张**整洁的长表**（一行一个观测、一列一个字段），它就能自动处理分组、配色、误差线等统计细节，一行代码得到一张专业图表。它是"探索数据时快速画统计图"的最佳选择。

# %% [markdown]
# ## Seaborn 的学习主线
#
# 提出统计问题 → 整理成长表 → 明确 x、y、hue 和分组 → 绘制统计图 → 比较类别和分布 → 处理排序与不确定性 → 用文字解释结论
#
# 先确认每一行是一条观察，再决定图形统计什么。看到均值、箱体或置信区间时，要说明它们代表什么，不能只描述颜色和形状。

# %% [markdown]
# ## 本模块练习方式
#
# 基础：完成一张分组图；提高：改变分组或排序并比较结论；挑战：同时保留摘要和原始点，说明样本量对解读的影响。
#
# 完成后请写下：输入是什么、处理做了什么、输出说明了什么、还存在什么限制。

# %% [markdown]
# ## 本章目标
#
# 学完本章，你将能够：
#
# - **理解**：理解 Seaborn 在统计可视化上的定位及它与 Matplotlib 的关系。
# - **操作**：能用 seaborn 的接口画出分布/关系类统计图。
# - **迁移**：能对一组分组数据画出统计图并比较不同分组的差异。

# %% [markdown]
# ## 44.1 这个模块解决什么问题
#
# **背景引入**：有时你想快速查看"不同类型商品的平均销量差多少、数据分布如何"，逐步手写 Matplotlib 太慢。
#
# 打个比方：Matplotlib 像一盒需要自己动手拼的积木——颜色、刻度、图例都得你一块块搭；Seaborn 则像一份说明书完备的'统计图积木包'——你只要把整洁的长表、x/y/hue 报给它，它就把分组、配色、误差线这些重复劳动一手包办。想快速'看一眼数据什么样'，选它最省力。
#
# - **长表即输入**：给 data + x/y/hue 就能出图，不用手动分组；
#
# - **统计自动化**：自动含误差线、回归线、密度曲线等统计细节；
#
# - **多变量对比**：用 hue / col / row 一次看多个分组维度。

# %% [markdown]
# ## 44.2 学习地图
#
#
#
# 这个模块是一张不断扩展的"统计图表图谱"：
#
#
#
# 1. **40.3 数据结构与主题**：先理解为何"长表+要选hue"就够；
#
# 2. **40.4 频数图 / 统计柱状图 / 点图**：看类别间差异；
#
# 3. **40.5 箱线图 / 小提琴图 / 抖动散点 / 蜂群图**：看分布；
#
# 4. **40.6 直方图 / 核密度图 / 累积分布**：连续变量分布；
#
# 5. **40.7 散点图 / 统计折线 / 回归图**：两变量关系；
#
# 6. **40.8 联合分布 / 成对关系 / 热力图 / 聚类热力图 / 分面图**：多变量探索。
#
#
#
# 前面是 Pandas 的整洁数据，后面是 Plotly 的交互式图表。

# %% [markdown]
# ## 44.3 第一个上手示例
#
#
#
# 感受"一行代码出统计图"。运行下方代码：画出不同品类销量的分布箱线图。

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams["font.sans-serif"] = ["font.sans-serif", "Microsoft YaHei", "SimHei", "DejaVu Sans"]
plt.rcParams["axes.unicode_minus"] = False


orders = pd.DataFrame(
    {
        "品类": ["餐饮"] * 3 + ["购物"] * 3 + ["交通"] * 3,
        "金额": [35.5, 48, 52, 120, 299, 150, 18, 25, 30],
    }
)
sns.boxplot(data=orders, x="品类", y="金额")
plt.title("不同品类金额分布")
plt.show()

# %% [markdown]
# <!-- module-intro-checkpoint:intro-seaborn -->
# ## 44.4 入门验收｜先固定统计问题，再比较两组分布
#
# **应用背景：** 你要比较新老客户的客单价差异。请保留每一条客户记录，用箱线图观察中心、离散与异常点。
#
# **你需要完成：**
#
# 1. 创建包含 `customer_type` 与 `amount` 的 DataFrame。
# 2. 以客户类型为 x、金额为 y 绘制箱线图。
# 3. 写出一句结果解读，不能只说“图画出来了”。
#
# **操作提示：** Seaborn 偏好一行一个观测的长表；使用 `sns.boxplot(data=df, x=..., y=...)`。
#
# **验收标准：** 图中有新客、老客两个箱体，解读同时提到中心或离散，并保留样本限制。

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

customer_type = ["新客"] * 5 + ["老客"] * 5
amount = [68, 75, 82, 90, 110, 88, 105, 120, 135, 160]
customers = pd.DataFrame({"customer_type": customer_type, "amount": amount})

# TODO 1：绘制两类客户的金额箱线图
...

# TODO 2：根据中位数与离散程度写一句解读
finding = "..."
print(finding)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

customer_type = ["新客"] * 5 + ["老客"] * 5
amount = [68, 75, 82, 90, 110, 88, 105, 120, 135, 160]
customers = pd.DataFrame({"customer_type": customer_type, "amount": amount})

sns.boxplot(data=customers, x="customer_type", y="amount")
plt.title("新老客户客单价分布")
finding = "样例中老客的客单价中位数更高，分布也更分散；仍需更多样本验证。"
print(finding)
plt.show()

# %% [markdown]
# ## 44.5 小结
# ### 你已经了解
#
#
#
# - Seaborn 用"长表 + 统计维度"一句话出图，省去手动分组和配色；
#
# - 它能自动加误差线、回归线等统计细节；
#
# - 是探索数据时快速画统计图的首选工具。
#
#
#
# ### 自测清单
#
#
#
# - [ ] 能说出 Seaborn 与 Matplotlib 的分工；
#
# - [ ] 能用 seaborn 画一张分类箱线图；
#
# - [ ] 知道给 Seaborn 提供"整洁长表"的前提。
#
#
#
# > **模块核心口诀**：给一张长表，选定 x/y/hue，Seaborn 帮你画；先打基础图，再看多变量。

# %% [markdown]
# ## 教学实验：分组比较与不确定性
#
# 这一组实验专门训练“观察一个结果 → 只改一个变量 → 解释变化”。先运行第一个代码单元格，再运行第二个。

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

report = pd.DataFrame(
    {
        "region": ["华东", "华南", "华北", "西南"],
        "sales": [320, 250, 280, 190],
    }
)
fig, ax = plt.subplots(figsize=(7, 3.5))
sns.barplot(
    data=report, x="region", y="sales", ci=None, ax=ax, color="#0F766E"
)
ax.set_title("地区销售额比较")
ax.set_ylabel("销售额")
plt.show()

# %% [markdown]
# ### 第一个结果怎么读
#
# Seaborn 负责把 DataFrame 的字段映射为图形编码；先明确横轴、纵轴和每行数据的粒度，再选择图表。
#
# 请记录：输入是什么、输出是什么、输出支持了哪一个结论。

# %%
report = report.sort_values("sales", ascending=False)
fig, ax = plt.subplots(figsize=(7, 3.5))
sns.barplot(
    data=report, x="sales", y="region", ci=None, ax=ax, color="#F59E0B"
)
ax.set_title("按销售额排序的地区比较")
ax.set_xlabel("销售额")
ax.set_ylabel("地区")
plt.show()

# %% [markdown]
# ### 第二个结果怎么读
#
# 第二个实验只改变排序和坐标方向，让读者更容易找到最大值。图表调整必须服务于阅读任务。
#
# 迁移任务：把一个输入值、一个字段或一个图表参数换成自己的例子，再用一句话解释变化。

# %% [markdown]
# ## 错误恢复：分组字段缺失怎么办
#
# 真实数据和真实代码都会出问题。本节先观察问题，再用一个明确的检查或修复步骤恢复运行。

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

report = pd.DataFrame({"region": ["华东", "华南"], "sales": [120, 150]})
required = {"region", "sales"}
missing = required - set(report.columns)
if missing:
    print("缺少字段：", sorted(missing))
else:
    fig, ax = plt.subplots(figsize=(6, 3))
    sns.barplot(data=report, x="region", y="sales", ci=None, ax=ax)
    ax.set_title("地区销售额")
    plt.show()

# %% [markdown]
# ### 错误恢复步骤
#
# 1. 先看错误类型、字段或数据形状。
# 2. 判断问题发生在输入、处理中间结果还是输出。
# 3. 修复后重新检查结果，而不是只让代码不报错。
#
# 绘图前先检查字段是否存在。把字段检查放在画图之前，错误会更接近真正原因，也更容易恢复。
#
# 迁移任务：把示例中的输入换成一组会触发问题的数据，并记录你的修复规则。
