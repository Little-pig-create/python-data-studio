# %% [markdown]
# # 第4章 列表与元组（list / tuple）
#
# 理解列表的可变性和元组的不可变性，能够管理有序数据集合。

# %% [markdown]
# ## 本章教学增强提示
#
# - 模块：**Python 基础**；本章结果重点：变量、数据结构、文件和异常路径的可观察输出。
# - 本章的“课堂自检”用于即时验证理解，不再作为独立章节作业提交。
# - 阅读输出时，请同时记录输入口径、关键中间结果和结论边界。

# %% [markdown]
# ## 先解决一个小问题
#
# 整理一周订单金额和课程成绩：需要追加记录、删除异常值、排序，并保留一份不应被修改的基准数据。

# %% [markdown]
# ## 这章为什么先学
#
# 列表和元组是后续批量计算的基础容器。先理解可变与不可变，能减少数据被意外改写的问题。

# %% [markdown]
# ## 开始前确认
#
# - 掌握字符串和基本运算
# - 能读取列表中的元素并进行简单遍历

# %% [markdown]
# ## 做完要留下什么
#
# 完成一个列表清洗流程，并用元组保存不可变的范围或多值结果。

# %% [markdown]
# ## 运行规则
#
# 代码单元格按依赖顺序执行；需要复现结果时从上到下运行，并保留输入、计算和输出。

# %% [markdown]
# ## 本章要会
#
# - 创建和访问列表与元组
# - 执行列表增删改查
# - 排序、复制和推导
# - 使用元组解包返回多值

# %% [markdown]
# ## 核心概念
#
# - 列表适合需要修改的有序集合，元组适合固定结构记录。
# - 浅复制可以避免两个变量意外共享同一列表。
# - 推导式适合简单映射和筛选，复杂逻辑使用普通循环。

# %% [markdown]
# ## 本章方法与函数详解
#
# 下面按方法逐项学习。每个方法都有独立说明和独立代码单元格，便于单独运行、修改参数并观察结果。

# %% [markdown]
# ### scores.append
#
# 列表末尾追加一个元素。
#
# - **调用形式**：`values = [10, 20]`
# - **返回结果**：返回 None；直接修改原列表
# - **注意事项**：一次追加一个元素，不能把多个元素自动展开
#
# 先运行下面的最小示例，再回到本章案例观察它在真实数据中的用法。
#
# <!-- 教学增强：方法字段 -->
#
# #### 方法说明
#
# - **作用**：说明 `scores.append` 在本章任务中解决的问题。
# - **调用形式**：以当前代码 Cell 为准，补充对象、参数和默认值。
# - **参数**：先从下方独立代码 Cell 标出输入参数、默认值、数据类型和是否必填。
# - **返回值**：通常返回 None（`pop()` 返回被删除的元素）。
# - **原对象是否改变**：会改变原对象或模型状态；不要把返回值误认为新对象。
# - **错误与边界**：检查空输入、缺失值、类型不匹配、越界、形状不一致或格式不匹配；文件和图形方法还要检查路径与输出副作用。
# - **相近方法区别**：与本章相近方法比较输入、返回值、是否修改原对象和适用场景。
#
# #### 学习动作
#
# 先独立运行下一个代码 Cell，记录输入、输出、类型和形状；再修改一个参数，比较结果变化，并写出“观察到—说明—限制—下一步”。

# %%
values = [10, 20]
values.append(30)
print("append 后:", values)

# %% [markdown]
# ### scores.extend
#
# 把多个元素追加到列表末尾。
#
# - **调用形式**：`values = [10, 20]`
# - **返回结果**：返回 None；直接修改原列表
# - **注意事项**：参数应是可迭代对象
#
# 先运行下面的最小示例，再回到本章案例观察它在真实数据中的用法。
#
# <!-- 教学增强：方法字段 -->
#
# #### 方法说明
#
# - **作用**：说明 `scores.extend` 在本章任务中解决的问题。
# - **调用形式**：以当前代码 Cell 为准，补充对象、参数和默认值。
# - **参数**：先从下方独立代码 Cell 标出输入参数、默认值、数据类型和是否必填。
# - **返回值**：通常返回 None（`pop()` 返回被删除的元素）。
# - **原对象是否改变**：会改变原对象或模型状态；不要把返回值误认为新对象。
# - **错误与边界**：检查空输入、缺失值、类型不匹配、越界、形状不一致或格式不匹配；文件和图形方法还要检查路径与输出副作用。
# - **相近方法区别**：与本章相近方法比较输入、返回值、是否修改原对象和适用场景。
#
# #### 学习动作
#
# 先独立运行下一个代码 Cell，记录输入、输出、类型和形状；再修改一个参数，比较结果变化，并写出“观察到—说明—限制—下一步”。

# %%
values = [10, 20]
values.extend([30, 40])
print("extend 后:", values)

# %% [markdown]
# ### scores.pop
#
# 删除并返回指定位置的元素。
#
# - **调用形式**：`values = [10, 20, 30]`
# - **返回结果**：被删除的元素
# - **注意事项**：空列表或索引越界会失败
#
# 先运行下面的最小示例，再回到本章案例观察它在真实数据中的用法。
#
# <!-- 教学增强：方法字段 -->
#
# #### 方法说明
#
# - **作用**：说明 `scores.pop` 在本章任务中解决的问题。
# - **调用形式**：以当前代码 Cell 为准，补充对象、参数和默认值。
# - **参数**：先从下方独立代码 Cell 标出输入参数、默认值、数据类型和是否必填。
# - **返回值**：通常返回 None（`pop()` 返回被删除的元素）。
# - **原对象是否改变**：会改变原对象或模型状态；不要把返回值误认为新对象。
# - **错误与边界**：检查空输入、缺失值、类型不匹配、越界、形状不一致或格式不匹配；文件和图形方法还要检查路径与输出副作用。
# - **相近方法区别**：与本章相近方法比较输入、返回值、是否修改原对象和适用场景。
#
# #### 学习动作
#
# 先独立运行下一个代码 Cell，记录输入、输出、类型和形状；再修改一个参数，比较结果变化，并写出“观察到—说明—限制—下一步”。

# %%
values = [10, 20, 30]
removed = values.pop(1)
print("删除:", removed, "剩余:", values)

# %% [markdown]
# ### sorted
#
# 返回排序后的新列表。
#
# - **调用形式**：`values = [30, 10, 20]`
# - **返回结果**：新列表
# - **注意事项**：不会修改原列表
#
# 先运行下面的最小示例，再回到本章案例观察它在真实数据中的用法。
#
# <!-- 教学增强：方法字段 -->
#
# #### 方法说明
#
# - **作用**：说明 `sorted` 在本章任务中解决的问题。
# - **调用形式**：以当前代码 Cell 为准，补充对象、参数和默认值。
# - **参数**：先从下方独立代码 Cell 标出输入参数、默认值、数据类型和是否必填。
# - **返回值**：返回处理后的对象、数值、布尔值或结果数组，需用 `type()`、`shape` 或 `print()` 核对。
# - **原对象是否改变**：原对象通常不变，返回新对象。
# - **错误与边界**：检查空输入、缺失值、类型不匹配、越界、形状不一致或格式不匹配；文件和图形方法还要检查路径与输出副作用。
# - **相近方法区别**：与本章相近方法比较输入、返回值、是否修改原对象和适用场景。
#
# #### 学习动作
#
# 先独立运行下一个代码 Cell，记录输入、输出、类型和形状；再修改一个参数，比较结果变化，并写出“观察到—说明—限制—下一步”。

# %%
values = [30, 10, 20]
print("原列表:", values)
print("升序:", sorted(values))
print("降序:", sorted(values, reverse=True))

# %% [markdown]
# ### round
#
# 按指定小数位舍入。
#
# - **调用形式**：`amount = 1280.567`
# - **返回结果**：数值
# - **注意事项**：明确是展示舍入还是计算舍入
#
# 先运行下面的最小示例，再回到本章案例观察它在真实数据中的用法。
#
# <!-- 教学增强：方法字段 -->
#
# #### 方法说明
#
# - **作用**：说明 `round` 在本章任务中解决的问题。
# - **调用形式**：以当前代码 Cell 为准，补充对象、参数和默认值。
# - **参数**：先从下方独立代码 Cell 标出输入参数、默认值、数据类型和是否必填。
# - **返回值**：返回处理后的对象、数值、布尔值或结果数组，需用 `type()`、`shape` 或 `print()` 核对。
# - **原对象是否改变**：原对象通常不变，返回新对象。
# - **错误与边界**：检查空输入、缺失值、类型不匹配、越界、形状不一致或格式不匹配；文件和图形方法还要检查路径与输出副作用。
# - **相近方法区别**：与本章相近方法比较输入、返回值、是否修改原对象和适用场景。
#
# #### 学习动作
#
# 先独立运行下一个代码 Cell，记录输入、输出、类型和形状；再修改一个参数，比较结果变化，并写出“观察到—说明—限制—下一步”。

# %%
amount = 1280.567
print(round(amount, 2))

# %% [markdown]
# ### min
#
# 取得最小值。
#
# - **调用形式**：`values = [10, 20, 5]`
# - **返回结果**：元素中的最小值
# - **注意事项**：空序列会失败
#
# 先运行下面的最小示例，再回到本章案例观察它在真实数据中的用法。
#
# <!-- 教学增强：方法字段 -->
#
# #### 方法说明
#
# - **作用**：说明 `min` 在本章任务中解决的问题。
# - **调用形式**：以当前代码 Cell 为准，补充对象、参数和默认值。
# - **参数**：先从下方独立代码 Cell 标出输入参数、默认值、数据类型和是否必填。
# - **返回值**：返回处理后的对象、数值、布尔值或结果数组，需用 `type()`、`shape` 或 `print()` 核对。
# - **原对象是否改变**：原对象通常不变，返回新对象。
# - **错误与边界**：检查空输入、缺失值、类型不匹配、越界、形状不一致或格式不匹配；文件和图形方法还要检查路径与输出副作用。
# - **相近方法区别**：与本章相近方法比较输入、返回值、是否修改原对象和适用场景。
#
# #### 学习动作
#
# 先独立运行下一个代码 Cell，记录输入、输出、类型和形状；再修改一个参数，比较结果变化，并写出“观察到—说明—限制—下一步”。

# %%
values = [10, 20, 5]
print(min(values))

# %% [markdown]
# ### max
#
# 取得最大值。
#
# - **调用形式**：`values = [10, 20, 5]`
# - **返回结果**：元素中的最大值
# - **注意事项**：空序列会失败
#
# 先运行下面的最小示例，再回到本章案例观察它在真实数据中的用法。
#
# <!-- 教学增强：方法字段 -->
#
# #### 方法说明
#
# - **作用**：说明 `max` 在本章任务中解决的问题。
# - **调用形式**：以当前代码 Cell 为准，补充对象、参数和默认值。
# - **参数**：先从下方独立代码 Cell 标出输入参数、默认值、数据类型和是否必填。
# - **返回值**：返回处理后的对象、数值、布尔值或结果数组，需用 `type()`、`shape` 或 `print()` 核对。
# - **原对象是否改变**：原对象通常不变，返回新对象。
# - **错误与边界**：检查空输入、缺失值、类型不匹配、越界、形状不一致或格式不匹配；文件和图形方法还要检查路径与输出副作用。
# - **相近方法区别**：与本章相近方法比较输入、返回值、是否修改原对象和适用场景。
#
# #### 学习动作
#
# 先独立运行下一个代码 Cell，记录输入、输出、类型和形状；再修改一个参数，比较结果变化，并写出“观察到—说明—限制—下一步”。

# %%
values = [10, 20, 5]
print(max(values))

# %% [markdown]
# ### 方法学习检查
#
# - [ ] 能说明每个方法的输入、参数和返回结果
# - [ ] 能独立运行对应代码单元格
# - [ ] 能修改至少一个参数并解释输出变化
# - [ ] 能说明该方法是否修改原对象以及适用边界
#
# <!-- 教学增强：方法字段 -->
#
# #### 方法说明
#
# - **作用**：说明 `方法学习检查` 在本章任务中解决的问题。
# - **调用形式**：以当前代码 Cell 为准，补充对象、参数和默认值。
# - **参数**：先从下方独立代码 Cell 标出输入参数、默认值、数据类型和是否必填。
# - **返回值**：返回处理后的对象、数值、布尔值或结果数组，需用 `type()`、`shape` 或 `print()` 核对。
# - **原对象是否改变**：原对象通常不变，返回新对象。
# - **错误与边界**：检查空输入、缺失值、类型不匹配、越界、形状不一致或格式不匹配；文件和图形方法还要检查路径与输出副作用。
# - **相近方法区别**：与本章相近方法比较输入、返回值、是否修改原对象和适用场景。
#
# #### 学习动作
#
# 先独立运行下一个代码 Cell，记录输入、输出、类型和形状；再修改一个参数，比较结果变化，并写出“观察到—说明—限制—下一步”。

# %% [markdown]
# ## 示例 1：列表增删改查
#
# append添加单个元素，extend添加多个元素。

# %%
scores = [85, 92, 78]
scores.append(96)
scores.extend([88, 91])
scores[2] = 80
removed = scores.pop(0)
print("删除:", removed)
print("当前:", scores)

# %% [markdown]
# ## 示例 2：排序与推导式
#
# sorted返回新列表，list.sort原地修改。

# %%
sorted_scores = sorted(scores, reverse=True)
passed = [score for score in scores if score >= 90]
scaled = [round(score / 100, 2) for score in scores]
print(sorted_scores)
print("90分以上:", passed)
print("标准化:", scaled)

# %% [markdown]
# ## 示例 3：元组与解包
#
# 固定字段记录可用元组表示并直接解包。

# %%
order = ("A102", "华东", 1280.5)
order_id, region, amount = order
minimum, maximum = min(scores), max(scores)
print(order_id, region, amount)
print("范围:", (minimum, maximum))

# %% [markdown]
# ## 常见误区
#
# - 用=复制列表导致两个变量指向同一对象
# - 把sort的返回值赋给变量，得到None
# - 试图直接修改元组中的元素

# %% [markdown]
# ## 本章小结
#
# 理解列表的可变性和元组的不可变性，能够管理有序数据集合。
#
# **迁移思考**：
#
# 1. 如果需要筛选前10名的订单金额，除了排序+切片，还可以用什么方法？
# 2. 为什么用 = 复制列表会导致两个变量共享同一对象？应该如何正确复制？

# %% [markdown]
# ### 你已经掌握
#
# - 创建和访问列表与元组
# - 执行列表增删改查
# - 排序、复制和推导
# - 使用元组解包返回多值

# %% [markdown]
# ### 验收标准
#
# - 输入、计算和输出单元格完整。
# - 关键变量类型、形状或数值可核对。
# - 结论引用输出证据，并注明适用范围。

# %% [markdown]
# ### 关键知识速查
#
# | 知识点 | 作用与提醒 | 关键写法 |
# | --- | --- | --- |
# | 列表增删改查 | append添加单个元素，extend添加多个元素。 | `scores.append()`、`scores.extend()`、`scores.pop()`、`scores[2]` |
# | 排序与推导式 | sorted返回新列表，list.sort原地修改。 | `sorted()` |
# | 元组与解包 | 固定字段记录可用元组表示并直接解包。 | `min()`、`max()` |

# %% [markdown]
# ### 需要注意
#
# - 用=复制列表导致两个变量指向同一对象
# - 把sort的返回值赋给变量，得到None
# - 试图直接修改元组中的元素

# %% [markdown]
# ### 完成检查
#
# - [ ] 能够创建和访问列表与元组
# - [ ] 能够执行列表增删改查
# - [ ] 能够排序、复制和推导
# - [ ] 能够使用元组解包返回多值

# %% [markdown]
# ### 排错顺序
#
# 1. 从上到下重新运行依赖单元格。
# 2. 检查变量类型、列名、形状和缺失值。
# 3. 缩小输入范围，定位产生错误的最小步骤。
# 4. 修复后重新运行完整流程。
