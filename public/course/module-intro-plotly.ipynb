# %% [markdown]
# # Plotly 模块入门
#
# <!-- module-learning-arc:start -->
# > **Plotly 模块主线｜第 1 / 18 步：建立交互图结构与 Hover 体验**
# >
# > **持续应用背景：** 准备周度经营预警会：让读者通过悬停、缩放、下钻和层级探索，沿着异常、定位、行动的路径完成追问。
# >
# > **承接上一阶段：** 模块入门与应用任务  →  **本章任务：** Plotly 模块入门  →  **下一步：** 图表结构与Hover
# >
# > **大作业连接：** 本章练习将成为《周度经营预警会：交互诊断与行动看板》的一部分，最终需要把诊断和行动视图组织成支持经营预警决策的可分享 HTML。
# <!-- module-learning-arc:end -->

# %% [markdown]
# ## 学习目标
#
# 完成“Plotly 模块入门”后，你应该能够：
#
# 1. 能先完成一个默认可读的图，再添加服务于问题的交互。
# 2. 能用标题、单位和 hover 明细解释图表编码。
# 3. 能判断一个交互控件是否真正帮助比较，而不是增加干扰。

# %% [markdown]
# ## 运行后应观察
#
# 运行示例后，应先检查默认视图是否可读，再悬停查看明细。交互应补充比较信息，而不能替代标题、单位或坐标轴。
#
# 如果暂时没有输出，先确认是否按顺序运行了前置单元格；再检查变量名、数据形状或路径，而不是直接跳到参考实现。

# %% [markdown]
# ## 初学者学习路线
#
# 这章建议按照“先观察、再模仿、后修改、最后独立完成”的顺序学习，不必一次记住所有参数。
#
# 1. 先阅读任务说明，明确这段代码要回答什么问题。
# 2. 运行一个最小例子，先观察输入、输出和数据形状，再回看每一行代码。
# 3. 只修改一个参数或一条数据，重新运行并比较前后结果。
# 4. 完成“综合练习”，最后再看本章小结，把能迁移到其他数据的问题写下来。
#
# 运行时如果看到 NameError，通常是前置单元格还没有运行；如果输出和预期不同，先检查变量是否被后面的单元格重新赋值。

# %% [markdown]
# ## 先做一个小检查
#
# 进入正式例子前，先用一句话回答：本章的输入是什么，想得到什么结果？
#
# 本章主题是“Plotly 模块入门”。请特别留意三件事：输入的类型或形状、处理中间变量的含义、最后输出能否支持一个清楚的结论。

# %% [markdown]
# ## 本章场景
#
#
#
# 前面画的是静态图——输出就是一张定格图片。当你想在页面上"鼠标悬停看清数值、拖拽缩放、点击隐藏某条线"时，静态图就办不到了。
#
#
#
# **Plotly** 画的是**交互式图表**：悬停能看数据、缩放、联动，非常适合运营看板、数据报告、演示汇报。它用 `px.` 一行生成图（快速出图），需要精细控制时再用 `go.`（子图、3D、地图）。学会它，你就能做出"能交互的数据看板"。

# %% [markdown]
# ## Plotly 的学习主线
#
# 先完成静态视图 → 增加 hover 明细 → 统一标题和单位 → 增加筛选或按钮 → 调整布局与响应式阅读 → 导出交互结果
#
# 每个交互功能都要服务于一个分析问题。先检查默认视图是否可读，再增加交互；悬停提示是补充信息，不能替代坐标轴和标题。

# %% [markdown]
# ## 本模块练习方式
#
# 基础：完成一个可读交互图；提高：增加明细提示；挑战：设计一个筛选或切换控件，并说明它如何减少认知负担。
#
# 完成后请写下：输入是什么、处理做了什么、输出说明了什么、还存在什么限制。

# %% [markdown]
# ## 本章目标
#
# 学完本章，你将能够：
#
# - **理解**：理解 Plotly 面向交互式可视化的定位与图对象（Figure）概念。
# - **操作**：能用 plotly.express 画一个基础交互图并查看 hover。
# - **迁移**：能把一份经营表变成可交互探索的图表用于汇报。

# %% [markdown]
# ## 64.1 这个模块解决什么问题
#
#
#
# **背景引入**：看静态报表时，想看清某根折线背后的具体数值，还得回表格里翻；而交互图悬停即现。
#
#
#
# - **交互默认内置**：悬停看数、图例点击显隐、拖拽缩放；
#
# - **px 快速出图**：`px.line`、`px.bar` 一行生成；
#
# - **go 精细控制**：子图组合、坐标轴联动、地图、3D。

# %% [markdown]
# ## 64.2 学习地图
#
#
#
# 本模块先建骨架、再逐图展开：
#
#
#
# 1. **59.3 图表结构与 Hover**：Figure / trace / layout 与悬停信息；
#
# 2. **59.4 折线图 / 柱状图 / 散点图 / 气泡图 / 面积图**：基础交互图；
#
# 3. **59.5 直方图 / 箱线图 / 小提琴图 / 热力图**：分布类图；
#
# 4. **59.6 矩形树图 / 旭日图 / 漏斗图 / 瀑布图**：结构类图；
#
# 5. **59.7 时间线·甘特图 / 地图**：专题图；
#
# 6. **59.8 子图、控件与导出**：组合多图、加点控件、导出成品。
#
#
#
# 前面是 Pandas 数据 + 基础绘图，学完你就具备"做交互数据看板"的能力。

# %% [markdown]
# ## 64.3 第一个上手示例
#
#
#
# 感受交互式折线图。运行下方代码：先出一张线图，再试着把鼠标悬停在点上看看数值。

# %%
import plotly.express as px

months = ["1月", "2月", "3月", "4月", "5月"]
sales = [120, 150, 180, 210, 160]

fig = px.line(x=months, y=sales, title="月度销量（交互）")
fig.show()

# %% [markdown]
# <!-- module-intro-checkpoint:intro-plotly -->
# ## 64.4 入门验收｜让经营趋势支持悬停追问
#
# **应用背景：** 经营会上不仅要看销售趋势，还要在悬停时核对目标值。请把两列指标放进同一份交互图信息中。
#
# **你需要完成：**
#
# 1. 用 `px.line` 绘制日期与销售额趋势。
# 2. 显示数据点，并把 `target` 加入 Hover。
# 3. 为图表设置能说明业务问题的标题。
#
# **操作提示：** 使用 `markers=True`，并把额外字段写入 `hover_data=[...]`。
#
# **验收标准：** 悬停任一点时能同时看到日期、销售额和目标值。

# %%
import pandas as pd
import plotly.express as px

weekly = pd.DataFrame({
    "date": pd.date_range("2026-08-03", periods=5, freq="D"),
    "sales": [120, 138, 132, 155, 168],
    "target": [130, 130, 140, 150, 160],
})

# TODO：创建带数据点、目标值 Hover 和业务标题的交互折线图
fig = ...
fig.show()

# %%
import pandas as pd
import plotly.express as px

weekly = pd.DataFrame({
    "date": pd.date_range("2026-08-03", periods=5, freq="D"),
    "sales": [120, 138, 132, 155, 168],
    "target": [130, 130, 140, 150, 160],
})

fig = px.line(
    weekly,
    x="date",
    y="sales",
    markers=True,
    hover_data=["target"],
    title="本周销售与目标核对",
)
fig.show()

# %% [markdown]
# ## 64.5 小结
# ### 你已经了解
#
#
#
# - Plotly 画交互式图表，悬停看数、缩放、联动是内置能力；
#
# - `px.` 一行生成图，`go.` 用于精细控制；
#
# - 适合做看板、报告、演示。
#
#
#
# ### 自测清单
#
#
#
# - [ ] 能说出 Plotly 与静态图的区别；
#
# - [ ] 能用 `px.line` 生成一张交互折线图；
#
# - [ ] 知道 `px.` 与 `go.` 的分工。
#
#
#
# > **模块核心口诀**：先 px 快速出图，悬停看数即交互；组合与控件在 go 里。

# %% [markdown]
# ## 教学实验：交互图与信息层次
#
# 这一组实验专门训练“观察一个结果 → 只改一个变量 → 解释变化”。先运行第一个代码单元格，再运行第二个。

# %%
import pandas as pd
import plotly.express as px

report = pd.DataFrame(
    {
        "region": ["华东", "华南", "华北", "西南"],
        "sales": [320, 250, 280, 190],
    }
)
fig = px.bar(report, x="region", y="sales", title="地区销售额")
fig.show()

# %% [markdown]
# ### 第一个结果怎么读
#
# Plotly 的基本流程是：准备表格、映射字段、设置标题、显示图形。悬停提示只能补充信息，不能替代坐标轴和单位。
#
# 请记录：输入是什么、输出是什么、输出支持了哪一个结论。

# %%
fig = px.bar(
    report.sort_values("sales", ascending=False),
    x="region",
    y="sales",
    text="sales",
    title="按销售额排序的地区销售额",
)
fig.update_traces(textposition="outside")
fig.update_layout(yaxis_title="销售额", xaxis_title="地区")
fig.show()

# %% [markdown]
# ### 第二个结果怎么读
#
# 第二个实验增加数值标签并排序。请检查：标签是否遮挡、标题是否准确、图形是否仍然能在窄屏阅读。
#
# 迁移任务：把一个输入值、一个字段或一个图表参数换成自己的例子，再用一句话解释变化。

# %% [markdown]
# ## 错误恢复：空数据还能不能画图
#
# 真实数据和真实代码都会出问题。本节先观察问题，再用一个明确的检查或修复步骤恢复运行。

# %%
import pandas as pd
import plotly.express as px

report = pd.DataFrame({"region": ["华东", "华南"], "sales": [120, 150]})
if report.empty:
    print("没有可绘制的数据，请先检查筛选条件。")
else:
    fig = px.bar(report, x="region", y="sales", title="地区销售额")
    fig.update_layout(yaxis_title="销售额", xaxis_title="地区")
    fig.show()

# %% [markdown]
# ### 错误恢复步骤
#
# 1. 先看错误类型、字段或数据形状。
# 2. 判断问题发生在输入、处理中间结果还是输出。
# 3. 修复后重新检查结果，而不是只让代码不报错。
#
# 筛选后先判断是否为空，再调用绘图函数。空表不是绘图库的问题，而是上游筛选口径需要检查。
#
# 迁移任务：把示例中的输入换成一组会触发问题的数据，并记录你的修复规则。
