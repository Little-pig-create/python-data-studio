# %% [markdown]
# # 模块大作业：综合数据分析小项目
#
# **模块知识综合练习**

# %% [markdown]
# ## 1. 项目背景与数据策略
#
# 从课程提供的数据或一份简单的自建数据中选择一个明确的小问题，完成从数据读取到结论表达的完整练习。

# %% [markdown]
# ## 2. 综合任务
#
# 写清问题和指标；至少组合两个课程模块的知识；完成数据清洗、统计、可视化和结果解释；提交数据说明、三条发现、两条限制和一份可复现 Notebook。

# %% [markdown]
# ## 4. 进阶完成规则
#
# 这是模块末尾的独立综合章节，难度高于普通章节。请把实现拆成至少 4 个独立代码 Cell：输入/质量、核心处理、比较/可视化、交付/解释。每个阶段打印中间结果，并用 `print()`、条件判断和错误提示检查，不使用 断言语句。公开数据不是强制条件，可使用课程本地快照、可复现模拟数据或合规公开数据。

# %% [markdown]
# ## 4. 开始前的项目约定
#
# - 固定随机种子；
# - 先检查路径、字段、行数和缺失值；
# - 每个阶段保留一个可核对的中间结果；
# - 不把结论写成超出数据范围的事实；
# - 从头运行 Notebook 后再提交。

# %%
project={"decision_owner":"请填写","question":"请填写一个可行动的问题","success_metric":"请填写可监测指标","data_source":"请填写来源"}
for key,value in project.items(): print(key,":",value)
print("下一步：完成数据卡片、质量审计和最小基线")

# %% [markdown]
# ## 5. 阶段性实现要求
#
# 不要把全部实现集中在一个 Cell。请新增独立 Cell，依次完成：
#
# - 阶段 A：输入与质量检查；
# - 阶段 B：核心变换、基线或统计；
# - 阶段 C：比较、可视化或评估；
# - 阶段 D：交付文件、结果解释和局限。

# %%
# 阶段计划记录
print("请在后续独立 Cell 中完成四个阶段，并记录每个阶段的验收结果。")

# %% [markdown]
# ## 6. 提交前自检
#
# - [ ] Notebook从头运行成功
# - [ ] 数据来源和本地路径已写明
# - [ ] 关键中间结果可核对
# - [ ] 图表完整且有解释
# - [ ] 结论有数据依据和边界
# - [ ] 没有依赖隐藏变量或外部网络

# %% [markdown]
# ## 7. 评分参考
#
# | 评分项 | 分值 |
# |---|---:|
# | 任务理解与问题定义 | 10 |
# | 数据处理与核心知识 | 35 |
# | 结果打印与可视化 | 20 |
# | 结果解释与限制 | 20 |
# | 代码规范与可复现性 | 15 |

# %% [markdown]
# ## 模块大作业交付自检
#
# 这是独立的大作业章节，不属于上一教学章节的 Cell。按“问题定义 → 数据质量 → 核心处理 → 结果表达 → 限制与下一步”逐项检查。

# %%
required_outputs = ["问题定义和数据来源", "数据质量检查", "核心结果", "可解释的表格或图形", "限制和下一步"]
for item in required_outputs: print("交付检查项:", item)
print("检查完成后再提交独立模块大作业。")

# %% [markdown]
# ### 最低完成标准
#
# - 重启内核后能够按顺序运行；
# - 数据来源、快照、字段和许可可追溯；
# - 关键结论有证据；
# - 不把相关性写成因果关系；
# - 使用打印和条件分支进行检查。
