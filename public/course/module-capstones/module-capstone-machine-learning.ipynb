# %% [markdown]
# # 模块大作业：客户转化预测与模型评估
#
# **模块知识综合练习**

# %% [markdown]
# ## 1. 项目背景与数据策略
#
# 使用课程本地客户营销数据，训练一个简单的分类模型，判断哪些客户更可能响应，并比较模型结果。

# %% [markdown]
# ## 2. 综合任务
#
# 完成特征类型检查、缺失值和类别编码；划分训练/测试集；比较两个基础 Pipeline；报告 accuracy、precision、recall、ROC-AUC 和混淆矩阵；解释模型局限。

# %% [markdown]
# ## 4. 进阶完成规则
#
# 这是模块末尾的独立综合章节，难度高于普通章节。请把实现拆成至少 4 个独立代码 Cell：输入/质量、核心处理、比较/可视化、交付/解释。每个阶段打印中间结果，并用 `print()`、条件判断和错误提示检查，不使用 断言语句。公开数据不是强制条件，可使用课程本地快照、可复现模拟数据或合规公开数据。

# %% [markdown]
# ## 4. 开始前的项目约定
#
# - 固定随机种子；
# - 先检查路径、字段、行数和缺失值；
# - 每个阶段保留一个可核对的中间结果；
# - 不把结论写成超出数据范围的事实；
# - 从头运行 Notebook 后再提交。

# %%
from pathlib import Path
import pandas as pd

data_path=Path("/datasets/bank_marketing_full.csv")
df=pd.read_csv(data_path, sep=";")
print("数据形状:", df.shape)
print("目标分布:"); print(df["y"].value_counts(normalize=True).round(4))
print("下一步：完成 duration 泄漏审计")

# %% [markdown]
# ## 5. 阶段性实现要求
#
# 不要把全部实现集中在一个 Cell。请新增独立 Cell，依次完成：
#
# - 阶段 A：输入与质量检查；
# - 阶段 B：核心变换、基线或统计；
# - 阶段 C：比较、可视化或评估；
# - 阶段 D：交付文件、结果解释和局限。

# %%
# 阶段计划记录
print("请在后续独立 Cell 中完成四个阶段，并记录每个阶段的验收结果。")

# %% [markdown]
# ## 6. 提交前自检
#
# - [ ] Notebook从头运行成功
# - [ ] 数据来源和本地路径已写明
# - [ ] 关键中间结果可核对
# - [ ] 图表完整且有解释
# - [ ] 结论有数据依据和边界
# - [ ] 没有依赖隐藏变量或外部网络

# %% [markdown]
# ## 7. 评分参考
#
# | 评分项 | 分值 |
# |---|---:|
# | 任务理解与问题定义 | 10 |
# | 数据处理与核心知识 | 35 |
# | 结果打印与可视化 | 20 |
# | 结果解释与限制 | 20 |
# | 代码规范与可复现性 | 15 |

# %% [markdown]
# ## 模块大作业交付自检
#
# 这是独立的大作业章节，不属于上一教学章节的 Cell。按“问题定义 → 数据质量 → 核心处理 → 结果表达 → 限制与下一步”逐项检查。

# %%
required_outputs = ["问题定义和数据来源", "数据质量检查", "核心结果", "可解释的表格或图形", "限制和下一步"]
for item in required_outputs: print("交付检查项:", item)
print("检查完成后再提交独立模块大作业。")

# %% [markdown]
# ### 最低完成标准
#
# - 重启内核后能够按顺序运行；
# - 数据来源、快照、字段和许可可追溯；
# - 关键结论有证据；
# - 不把相关性写成因果关系；
# - 使用打印和条件分支进行检查。
