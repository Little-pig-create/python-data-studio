# %% [markdown]
# # 第29章 直方图（hist）
#
# 通过分箱展示连续变量的频数或密度，判断集中区间、偏态和多峰。
#
# ## 学习目标
#
# 本章围绕一种明确的图表结构展开，先看最小可用示例，再加入分组、注释或交互细节。

# %% [markdown]
# ## 适用场景
#
# 探索一个连续数值变量的分布形状。
#
# ## 数据结构
#
# 一维连续数值样本；分组比较时各组应有足够样本量。
#
# ## 本章练习任务
#
# 运行基础图表后，完成以下任务：
#
# 1. 将 bins 参数从 18 改为 30，观察分箱数量对分布形状的影响
# 2. 添加 density=True 参数，对比频数直方图与密度直方图的纵轴含义
# 3. 修改 edgecolor 为 'black'，说明边框对柱形区分度的作用

# %% [markdown]
# ## 0. 准备可复现数据
#
# 先完成导入和数据准备，后续单元格只负责一种图表或一种分析动作。

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

rng = np.random.default_rng(25)
months = np.array(["1月", "2月", "3月", "4月", "5月", "6月"])
sales = np.array([120, 148, 139, 176, 205, 228])
profit = np.array([18, 24, 21, 32, 39, 47])
orders = np.array([1180, 1320, 1280, 1490, 1680, 1850])
regions = np.array(["华东", "华南", "华北", "西南"])
online = np.array([86, 72, 64, 48])
offline = np.array([42, 35, 38, 31])
samples = np.concatenate([rng.normal(180, 35, 180), rng.normal(320, 45, 45)])

print("数据准备完成：", len(months), "个月，", len(regions), "个区域")

# %% [markdown]
# ## 1. 基础图表
#
# 先保留必要的编码：位置、颜色或大小。图表标题、坐标轴和单位应能让读者脱离代码理解结果。

# %%
fig, ax = plt.subplots(figsize=(8, 4.2))
ax.hist(samples, bins=18, color="#1a73e8", edgecolor="white")
ax.set(title="订单金额分布", xlabel="订单金额（元）", ylabel="订单数")
ax.spines[["top", "right"]].set_visible(False)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 2. 进阶变体
#
# 在基础图表可读的前提下增加分组、布局、注释或交互。新增编码必须服务于一个明确问题。

# %%
regular = samples[samples < 260]
premium = samples[samples >= 260]
bins = np.linspace(samples.min(), samples.max(), 20)
fig, ax = plt.subplots(figsize=(8, 4.2))
ax.hist([regular, premium], bins=bins, stacked=True, label=["普通区间", "高价区间"], color=["#1a73e8", "#f9ab00"])
ax.set(title="订单金额分层分布", xlabel="订单金额（元）", ylabel="订单数")
ax.legend(frameon=False)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 3. 参数说明
#
# - bins：分箱
# - density：密度
# - range：统计范围
# - histtype：绘制方式

# %% [markdown]
# ## 4. 结果解读
#
# 关注中心、离散、偏态、峰数和长尾；改变分箱检查结论是否稳定。

# %% [markdown]
# ## 常见误区
#
# - 样本很少却使用过多分箱
# - 不同组使用不同分箱边界
# - 把柱高误解为单个精确值

# %% [markdown]
# ## 综合练习
#
# 请使用同一份数据完成下面任务，并说明你选择该图表的原因。

# %%
rng_hist = np.random.default_rng(290)
delivery_days = rng_hist.gamma(shape=2.4, scale=1.3, size=260)
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
axes[0].hist(delivery_days, bins=10, color="#188038", edgecolor="white")
axes[0].set(title="10个分箱", xlabel="配送天数")
axes[1].hist(delivery_days, bins=24, color="#188038", edgecolor="white")
axes[1].set(title="24个分箱", xlabel="配送天数")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 本章小结
#
# 通过分箱展示连续变量的频数或密度，判断集中区间、偏态和多峰。

# %% [markdown]
# ### 你已经掌握
#
# - 判断直方图（hist）的适用场景
# - 准备与图表匹配的数据结构
# - 从基础图表扩展到分组、注释或交互变体
# - 按照业务问题解读图表并说明结论边界

# %% [markdown]
# ### 图表选择速查
#
# | 选择要点 | 本章说明 |
# | --- | --- |
# | 适用场景 | 探索一个连续数值变量的分布形状。 |
# | 数据结构 | 一维连续数值样本；分组比较时各组应有足够样本量。 |
# | 结果解读 | 关注中心、离散、偏态、峰数和长尾；改变分箱检查结论是否稳定。 |

# %% [markdown]
# ### 关键参数
#
# | 参数 | 作用 |
# | --- | --- |
# | `bins` | 分箱 |
# | `density` | 密度 |
# | `range` | 统计范围 |
# | `histtype` | 绘制方式 |

# %% [markdown]
# ### 需要注意
#
# - 样本很少却使用过多分箱
# - 不同组使用不同分箱边界
# - 把柱高误解为单个精确值

# %% [markdown]
# ### 完成检查
#
# - [ ] 能判断什么问题适合使用直方图（hist）
# - [ ] 能准备符合要求的数据结构
# - [ ] 能独立完成基础图表和一个进阶变体
# - [ ] 能调整关键参数并解释视觉变化
# - [ ] 能根据图表写出有边界的数据结论
