# %% [markdown]
# # 课程环境初始化
#
# 本Notebook用于在浏览器端安装本课程的数据分析工具。首次运行需要联网下载，安装完成后会保存在当前浏览器的本地存储中。
#
# 安装完成后，可以打开课程目录中的任意章节Notebook继续学习。

# %%
import piplite

await piplite.install(["numpy", "pandas", "matplotlib", "seaborn", "plotly"])

print("课程环境安装完成，可以开始学习。")

# %% [markdown]
# ## 常见说明
#
# - JupyterLite在浏览器中运行Python，不会修改本机Python环境。
# - 浏览器刷新后，已安装的包通常保存在浏览器缓存中。
# - 使用JupyterLab左侧文件浏览器打开各章Notebook。
# - 修改后的Notebook可以从JupyterLab菜单中下载。
